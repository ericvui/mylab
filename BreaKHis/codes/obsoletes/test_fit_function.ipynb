# %%
import sys
sys.path.append('../')

from codes.data.load_data import load_files
from codes.model.vgg_network import VGG

# %%
batch_size = 16
volumn = 7909
total_batch = (volumn * 0.7)/batch_size

src_folder = "F:\\GraduateClass\\Thesis\\Dataset\\BreaKHis\\histology_slides\\breast" #"F:\\GraduateClass\\Thesis\\Dataset\\BreaKHis\\histology_slides\\breast"
datasets = load_files(src_folder,0.7, "*.png",volumn,1)
train = datasets[0]
test = datasets[1]
val = datasets[2]
train = train.shuffle(batch_size * 100)
train = train.batch(batch_size)
val = val.batch(batch_size)

# %%
from tensorflow.keras.applications import InceptionResNetV2

# %%
resnet = InceptionResNetV2(include_top=True)
# Out:
# ...
# 225214464/225209952 [==============================] - 63s 0us/step

# %%
# Out:
# <tf.Tensor 'block8_10/add:0' shape=(None, 8, 8, 2080) dtype=float32>

# %%
resnet.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization_v1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.layers import Flatten,Dense,Dropout,GlobalAveragePooling2D
import tensorflow.keras.regularizers as regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop

num_classes = 1
resnet = InceptionResNetV2(include_top=True)
x = resnet.get_layer('block8_10').output
x = GlobalAveragePooling2D()(x)
outputs = Dense(num_classes
                ,kernel_regularizer=regularizers.l2(0.01) 
                ,kernel_initializer = "random_uniform"
                , activation='softmax')(x)            
my_model = Model(inputs=[resnet.input], outputs=[outputs])

my_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

my_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 149, 149, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_203 (Bat (None, 149, 149, 32) 96          conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 149, 149, 32) 0           batch_normalization_v1_203[0][0]
# __________________________________________________________________________________________________
# ...
