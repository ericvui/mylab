# %%
import sys
sys.path.append('../')

from codes.data.load_data import load_files
from codes.model.vgg_network import VGG

# %%
batch_size = 16
volumn = 7909
total_batch = (volumn * 0.7)/batch_size

src_folder = "C:\\dataset\\BreaKHis_v1\\histology_slides\\breast" #"F:\\GraduateClass\\Thesis\\Dataset\\BreaKHis\\histology_slides\\breast"
datasets = load_files(src_folder,0.7, "*.png",volumn,1)
train = datasets[0]
test = datasets[1]
val = datasets[2]
train = train.shuffle(batch_size * 100)
train = train.batch(batch_size)
val = val.batch(batch_size)

# %%
epochs = 5
vgg = VGG()

train_loss, val_loss = vgg.train(train,val,epochs,batch_size,10,total_batch)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 4s 0us/step
# WARNING: Logging before flag parsing goes to stderr.
# W0501 10:27:53.442970   460 network.py:1619] Model inputs must come from `tf.keras.Input` (thus holding past layer metadata), they cannot be the output of a previous non-Input layer. Here, a tensor specified as input to "model" was not an Input tensor, it was generated by layer global_average_pooling2d.
# Note that input tensors are instantiated via `tensor = tf.keras.Input(shape)`.
# The tensor that caused the issue was: global_average_pooling2d/Mean:0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a839d1d5eca1> in <module>
#       1 epochs = 5
# ----> 2 vgg = VGG()
#       3
#       4 train_loss, val_loss = vgg.train(train,val,epochs,batch_size,10,total_batch)
#
# ~\codes\model\vgg_network.py in __init__(self, rows, cols, channels, num_classes)
#      16         self.num_classes = num_classes
#      17
# ---> 18         self.vgg = self.build_vgg16()
#      19
#      20     def build_vgg16(self):
#
# ~\codes\model\vgg_network.py in build_vgg16(self)
#      37                         ,kernel_initializer = "random_uniform"
#      38                         , activation='softmax')(d3)
# ---> 39         re_trained = Model(inputs=[model.output], outputs=[outputs])
#      40         re_trained.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      41
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\tensorflow\python\keras\engine\training.py in __init__(self, *args, **kwargs)
#     120
#     121   def __init__(self, *args, **kwargs):
# --> 122     super(Model, self).__init__(*args, **kwargs)
#     123     # initializing _distribution_strategy here since it is possible to call
#     124     # predict on a model without compiling it.
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\tensorflow\python\keras\engine\network.py in __init__(self, *args, **kwargs)
#     136         'inputs' in kwargs and 'outputs' in kwargs):
#     137       # Graph network
# --> 138       self._init_graph_network(*args, **kwargs)
#     139     else:
#     140       # Subclassed network
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     454     self._setattr_tracking = False  # pylint: disable=protected-access
#     455     try:
# --> 456       result = method(self, *args, **kwargs)
#     457     finally:
#     458       self._setattr_tracking = previous_value  # pylint: disable=protected-access
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\tensorflow\python\keras\engine\network.py in _init_graph_network(self, inputs, outputs, name)
#     282     # Keep track of the network's nodes and layers.
#     283     nodes, nodes_by_depth, layers, layers_by_depth = _map_graph_network(
# --> 284         self.inputs, self.outputs)
#     285     self._network_nodes = nodes
#     286     self._nodes_by_depth = nodes_by_depth
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\tensorflow\python\keras\engine\network.py in _map_graph_network(inputs, outputs)
#    1812                              'The following previous layers '
#    1813                              'were accessed without issue: ' +
# -> 1814                              str(layers_with_complete_input))
#    1815         for x in nest.flatten(node.output_tensors):
#    1816           computable_tensors.append(x)
#
# ValueError: Graph disconnected: cannot obtain value for tensor Tensor("input_1:0", shape=(None, 256, 256, 3), dtype=float32) at layer "input_1". The following previous layers were accessed without issue: []
